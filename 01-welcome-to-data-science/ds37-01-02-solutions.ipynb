# %% [markdown]
# # DS37-01-02: Python Practise
# ---

# %% [markdown]
# <a id="learning-objectives"></a>
# ## Learning Objectives
# *After completing this notebook, you will be able to:*
#
# - Perform list and string indexing operations
# - Import and use libraries

# %% [markdown]
# ---
#
# ## <font color='red'> List and string indexing
#
# Given the list below, perform list and/or string operations to replicate the following results. You might need to use list and string indexing, string concatenation (adding strings together), and some other string functions we encountered in Session 01. Pay close attention to upper and lowercase!
#
#
# * ``the quick brown fox``
#
#
# * ``a QUICK BROWN FOX``
#
#
# * ``[3,5,7,9]``
#
#
# * ``['pete','bob','sarah']``
#
#
# * ``etep``

# %%
my_list = ['a','banana',3,True,5,6,7,8,9,['sarah','bob','pete'],'the quick brown fox jumped over the lazy dog']

# %% [markdown]
# ``the quick brown fox``

# %%
my_list[-1][0:19]
# Out:
# 'the quick brown fox'

# %% [markdown]
# ``a QUICK BROWN FOX``

# %%
my_list[0] + ' ' + my_list[-1][4:19].upper()
# Out:
# 'a QUICK BROWN FOX'

# %% [markdown]
# ``[3,5,7,9]``

# %%
my_list[2:9:2]
# Out:
# [3, 5, 7, 9]

# %% [markdown]
# ``['pete','bob','sarah']``

# %%
my_list[9][::-1]
# Out:
# ['pete', 'bob', 'sarah']

# %% [markdown]
# ``etep``

# %%
my_list[9][-1][::-1]
# Out:
# 'etep'

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='red'> Importing and using libraries
#
# Pandas is a library we'll be using throughout this course- it's widely used for data manipulating, cleaning, and exploratory data analysis.
#
# We'll cover its basic functions in much more detail in the coming weeks, but let's use Pandas as an example in learning how to import libraries.
#
# Using your Google and/or Stackoverflow skills, find the standard short name we use to import Pandas, then fill in the gaps in the cell below to import it.

# %%
import pandas as pd #FILL IN THE GAP HERE

# %% [markdown]
# Pandas makes it very easy to read in data files- including CSVs and Excel files.
#
# Can you use the documentation (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) for the Pandas ``read_csv`` function to figure out how to read in our US Presidential Election Dataset?

# %%
election_dataset = pd.read_csv('./data/us_presidential_votes_clean.csv') # FILL IN THE GAPS HERE TO READ IN OUR DATASET

# %% [markdown]
# Now let's use the ``head`` command to preview the first 5 rows of our dataset.

# %%
election_dataset.head()
# Out:
#     Clinton     Trump state_abbr     county_name  population_2010  \
# 0  0.239569  0.734358         AL  Autauga County            54571
# 1  0.195653  0.773515         AL  Baldwin County           182265
# 2  0.466603  0.522714         AL  Barbour County            27457
# 3  0.214220  0.769662         AL     Bibb County            22915
# 4  0.084699  0.898519         AL   Blount County            57322
#
#    persons_under_5_years_percent_2014  persons_under_18_years_percent_2014  \
# 0                                 6.0                                 25.2
# 1                                 5.6                                 22.2
# 2                                 5.7                                 21.2
# 3                                 5.3                                 21.0
# 4                                 6.1                                 23.6
#
#    age65plus  female_persons_percent_2014  \
# 0       13.8                         51.4
# 1       18.7                         51.2
# 2       16.5                         46.6
# 3       14.8                         45.9
# 4       17.0                         50.5
#
#    living_in_same_house_1_year__over_percent_20092013  ...  \
# 0                                               85.0   ...
# 1                                               82.1   ...
# 2                                               84.8   ...
# 3                                               86.6   ...
# 4                                               88.7   ...
#
#    total_number_of_firms_2007  womenowned_firms_percent_2007  \
# 0                        4067                           31.7
# 1                       19035                           27.3
# 2                        1667                           27.0
# 3                        1385                            0.0
# 4                        4458                           23.2
#
#    manufacturers_shipments_2007_1000  merchant_wholesaler_sales_2007_1000  \
# 0                                  0                                    0
# 1                            1410273                                    0
# 2                                  0                                    0
# 3                                  0                                    0
# 4                             341544                                    0
#
#    retail_sales_2007_1000  retail_sales_per_capita_2007  \
# 0                  598175                         12003
# 1                 2966489                         17166
# 2                  188337                          6334
# 3                  124707                          5804
# 4                  319700                          5622
#
#    accommodation_and_food_services_sales_2007_1000  building_permits_2014  \
# 0                                            88157                    131
# 1                                           436955                   1384
# 2                                                0                      8
# 3                                            10757                     19
# 4                                            20941                      3
#
#    land_area_in_square_miles_2010  Density
# 0                          594.44     91.8
# 1                         1589.78    114.6
# 2                          884.88     31.0
# 3                          622.58     36.8
# 4                          644.78     88.9
#
# [5 rows x 39 columns]

# %% [markdown]
# Can you use the documentation for the ``head`` command (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) to figure out how to preview:
#
# * The first 10 rows of the dataset
# * The last 5 rows of the dataset

# %%
election_dataset.head(10)
# Out:
#     Clinton     Trump state_abbr      county_name  population_2010  \
# 0  0.239569  0.734358         AL   Autauga County            54571
# 1  0.195653  0.773515         AL   Baldwin County           182265
# 2  0.466603  0.522714         AL   Barbour County            27457
# 3  0.214220  0.769662         AL      Bibb County            22915
# 4  0.084699  0.898519         AL    Blount County            57322
# 5  0.750904  0.242289         AL   Bullock County            10914
# 6  0.427864  0.563155         AL    Butler County            20947
# 7  0.278559  0.692397         AL   Calhoun County           118572
# 8  0.418276  0.566338         AL  Chambers County            34215
# 9  0.145101  0.838713         AL  Cherokee County            25989
#
#    persons_under_5_years_percent_2014  persons_under_18_years_percent_2014  \
# 0                                 6.0                                 25.2
# 1                                 5.6                                 22.2
# 2                                 5.7                                 21.2
# 3                                 5.3                                 21.0
# 4                                 6.1                                 23.6
# 5                                 6.3                                 21.4
# 6                                 6.1                                 23.6
# 7                                 5.7                                 22.2
# 8                                 5.9                                 21.4
# 9                                 4.8                                 20.4
#
#    age65plus  female_persons_percent_2014  \
# 0       13.8                         51.4
# 1       18.7                         51.2
# 2       16.5                         46.6
# 3       14.8                         45.9
# 4       17.0                         50.5
# 5       14.9                         45.3
# 6       18.0                         53.6
# 7       16.0                         51.8
# 8       18.3                         52.3
# 9       20.9                         50.2
#
#    living_in_same_house_1_year__over_percent_20092013  ...  \
# 0                                               85.0   ...
# 1                                               82.1   ...
# 2                                               84.8   ...
# 3                                               86.6   ...
# 4                                               88.7   ...
# 5                                               84.7   ...
# 6                                               94.6   ...
# 7                                               83.6   ...
# 8                                               85.8   ...
# 9                                               90.6   ...
#
#    total_number_of_firms_2007  womenowned_firms_percent_2007  \
# 0                        4067                           31.7
# 1                       19035                           27.3
# 2                        1667                           27.0
# 3                        1385                            0.0
# 4                        4458                           23.2
# 5                         417                           38.8
# 6                        1769                            0.0
# 7                        8713                           24.7
# 8                        1981                           29.3
# 9                        2180                           14.5
#
#    manufacturers_shipments_2007_1000  merchant_wholesaler_sales_2007_1000  \
# 0                                  0                                    0
# 1                            1410273                                    0
# 2                                  0                                    0
# 3                                  0                                    0
# 4                             341544                                    0
# 5                                  0                                    0
# 6                             399132                                56712
# 7                            2679991                                    0
# 8                             667283                                    0
# 9                             307439                                62293
#
#    retail_sales_2007_1000  retail_sales_per_capita_2007  \
# 0                  598175                         12003
# 1                 2966489                         17166
# 2                  188337                          6334
# 3                  124707                          5804
# 4                  319700                          5622
# 5                   43810                          3995
# 6                  229277                         11326
# 7                 1542981                         13678
# 8                  264650                          7620
# 9                  186321                          7613
#
#    accommodation_and_food_services_sales_2007_1000  building_permits_2014  \
# 0                                            88157                    131
# 1                                           436955                   1384
# 2                                                0                      8
# 3                                            10757                     19
# 4                                            20941                      3
# 5                                             3670                      1
# 6                                            28427                      2
# 7                                           186533                    114
# 8                                            23237                      8
# 9                                            13948                      2
#
#    land_area_in_square_miles_2010  Density
# 0                          594.44     91.8
# 1                         1589.78    114.6
# 2                          884.88     31.0
# 3                          622.58     36.8
# 4                          644.78     88.9
# 5                          622.81     17.5
# 6                          776.83     27.0
# 7                          605.87    195.7
# 8                          596.53     57.4
# 9                          553.70     46.9
#
# [10 rows x 39 columns]

# %%
election_dataset.tail(10)
# Out:
#        Clinton     Trump state_abbr        county_name  population_2010  \
# 3102  0.088666  0.860447         WY    Niobrara County             2484
# 3103  0.173227  0.759533         WY        Park County            28205
# 3104  0.161211  0.770628         WY      Platte County             8667
# 3105  0.206245  0.723620         WY    Sheridan County            29116
# 3106  0.149872  0.793344         WY    Sublette County            10247
# 3107  0.194046  0.729428         WY  Sweetwater County            43806
# 3108  0.600608  0.321945         WY       Teton County            21294
# 3109  0.149261  0.764187         WY       Uinta County            21118
# 3110  0.143203  0.783580         WY    Washakie County             8533
# 3111  0.088182  0.869226         WY      Weston County             7208
#
#       persons_under_5_years_percent_2014  persons_under_18_years_percent_2014  \
# 3102                                 4.7                                 16.6
# 3103                                 5.5                                 20.5
# 3104                                 4.9                                 20.4
# 3105                                 5.6                                 21.6
# 3106                                 5.8                                 24.0
# 3107                                 7.3                                 27.0
# 3108                                 5.7                                 19.1
# 3109                                 7.6                                 29.8
# 3110                                 5.5                                 23.9
# 3111                                 6.5                                 21.6
#
#       age65plus  female_persons_percent_2014  \
# 3102       21.2                         54.3
# 3103       20.1                         50.1
# 3104       22.7                         49.1
# 3105       18.3                         50.0
# 3106       12.6                         46.3
# 3107        9.5                         48.1
# 3108       12.2                         48.2
# 3109       11.0                         49.6
# 3110       20.1                         49.3
# 3111       18.1                         47.4
#
#       living_in_same_house_1_year__over_percent_20092013  ...  \
# 3102                                               81.7   ...
# 3103                                               84.1   ...
# 3104                                               83.8   ...
# 3105                                               83.8   ...
# 3106                                               82.7   ...
# 3107                                               80.4   ...
# 3108                                               86.0   ...
# 3109                                               81.8   ...
# 3110                                               88.0   ...
# 3111                                               88.7   ...
#
#       total_number_of_firms_2007  womenowned_firms_percent_2007  \
# 3102                         463                            0.0
# 3103                        3896                           22.5
# 3104                        1065                           33.0
# 3105                        3524                           21.7
# 3106                        1559                           17.3
# 3107                        4052                           27.2
# 3108                        5974                           25.3
# 3109                        1983                           15.9
# 3110                         845                           26.9
# 3111                         810                           29.3
#
#       manufacturers_shipments_2007_1000  merchant_wholesaler_sales_2007_1000  \
# 3102                                  0                                    0
# 3103                              62727                               155545
# 3104                                  0                                34092
# 3105                                  0                                    0
# 3106                                  0                                    0
# 3107                                  0                               437493
# 3108                                  0                                    0
# 3109                                  0                               159375
# 3110                                  0                                12128
# 3111                                  0                                11540
#
#       retail_sales_2007_1000  retail_sales_per_capita_2007  \
# 3102                   19649                          8408
# 3103                  388380                         14271
# 3104                   93405                         11163
# 3105                  478180                         17110
# 3106                   82792                         10563
# 3107                  898189                         22843
# 3108                  515644                         25688
# 3109                  413983                         20626
# 3110                   98308                         12596
# 3111                   64312                          9395
#
#       accommodation_and_food_services_sales_2007_1000  building_permits_2014  \
# 3102                                             3071                      1
# 3103                                           132951                    131
# 3104                                            12103                     22
# 3105                                            66787                    117
# 3106                                            19746                     27
# 3107                                           150439                    227
# 3108                                           327363                    145
# 3109                                            35497                     40
# 3110                                            10175                      4
# 3111                                             7520                      1
#
#       land_area_in_square_miles_2010  Density
# 3102                         2626.04      0.9
# 3103                         6942.08      4.1
# 3104                         2084.21      4.2
# 3105                         2523.99     11.5
# 3106                         4886.54      2.1
# 3107                        10426.65      4.2
# 3108                         3995.38      5.3
# 3109                         2081.26     10.1
# 3110                         2238.55      3.8
# 3111                         2398.09      3.0
#
# [10 rows x 39 columns]

# %% [markdown]
# Let's check the type of this variable we've just created called ``election_dataset``. We see it's something called a 'DataFrame'.
#
# This is one of the most important types we'll be working with in this course; think of it as the Python equivalent of a table.

# %%
type(election_dataset)
# Out:
# pandas.core.frame.DataFrame
